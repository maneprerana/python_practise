# %%
name="Prerana"
age=22

# %% [markdown]
# #list and tuple
# a=[1,2,3]
# b=(1,2,3)

# %%
a=[1,2,3] 
b=(1,2,3)

# %% [markdown]
# #diff = and ==

# %%
a=5
a==5
# Out:
# True

# %% [markdown]
# #if-else statment

# %%
age=18
if age>=18:
    print("Adult")
else:
    print("Minor")
# Out:
# Adult

# %% [markdown]
# ## Function

# %%
def add(a,b):
    return a+b

# %% [markdown]
# ## Lambda function

# %%
square=lambda x:x*x

# %% [markdown]
# ##exception handaling

# %%
try:
    print(10/0)
except:
    print("Error")
# Out:
# Error

# %% [markdown]
# #dictionary

# %%
student={"name":"prerana","age":22}

# %%
a="10"
b=int(a)

# %% [markdown]
# ##Reverse string

# %%
text = "python"
print(text[::-1])
# Out:
# nohtyp

# %% [markdown]
# ## Even or odd

# %%
num=4
if num%2==0:
    print("even")
else:
    print("odd")
# Out:
# even

# %% [markdown]
# ## factorial

# %%
num=5
fact=1
for i in range (1,num+1):
    fact=fact*i
    print(fact)
# Out:
# 1
# 2
# 6
# 24
# 120

# %% [markdown]
# ## fibonacci series

# %%
a,b=0,1
for i in range (5):
    print(a)
    a,b=b,a+b
# Out:
# 0
# 1
# 1
# 2
# 3

# %% [markdown]
# ## palindrome

# %%
text="madam"
if text==text[::-1]:
    print("palindrome")
# Out:
# palindrome

# %% [markdown]
# ## prime number

# %%
num=7
for i in range (2,num):
    print("Not prime")
    break
else:
    print("prime")
# Out:
# Not prime
