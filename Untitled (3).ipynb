# %% [markdown]
# # tuple 26/6/25

# %%
mytuple2 = [43,69,99,12,6,90,67]
sorted(mytuple)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 mytuple2 = [43,69,99,12,6,90,67]
# ----> 2 sorted(mytuple)
#
# NameError: name 'mytuple' is not defined

# %% [markdown]
# # Set

# %%
A={1,2,3,4,5}
B={4,5,6,7,8}

# %%
A.intersection(B)
# Out:
# {4, 5}

# %%
A.difference(B)
# Out:
# {1, 2, 3}

# %%
B.difference(A)
# Out:
# {6, 7, 8}

# %%
t=(5,7,8,[9,10,11],12,13)
t[3].append(88)

# %%
t
# Out:
# (5, 7, 8, [9, 10, 11, 88], 12, 13)

# %%
l=
mylist[1]
# Out:
#   Cell In[23], line 1
#     mylist=[13,(11,12)[8,(5,4,[1,(2,3)],6,7),9,10])]
#                                                   ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %% [markdown]
# # dictionary
