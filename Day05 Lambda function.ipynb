# %% [markdown]
# ## Lambda Function

# %%
square = lambda x: x * x
print(square(5))
# Out:
# 25

# %%
add = lambda a, b: a + b
print(add(10, 20))
# Out:
# 30

# %%
maximum = lambda a, b: a if a > b else b
print(maximum(15, 10))
# Out:
# 15

# %%
even_odd = lambda x: "Even" if x % 2 == 0 else "Odd"
print(even_odd(8))
# Out:
# Even

# %%
students = [("Ram", 80), ("Sham", 70), ("Sita", 90)]

sorted_students = sorted(students, key=lambda x: x[1])

print(sorted_students)
# Out:
# [('Sham', 70), ('Ram', 80), ('Sita', 90)]

# %%
numbers = [1, 2, 3, 4, 5, 6]

even = list(filter(lambda x: x % 2 == 0, numbers))

print(even)
# Out:
# [2, 4, 6]

# %%
numbers = [1, 2, 3, 4, 5]

result = list(map(lambda x: x * 2, numbers))

print(result)
# Out:
# [2, 4, 6, 8, 10]

# %%
from functools import reduce

numbers = [1, 2, 3, 4]

product = reduce(lambda x, y: x * y, numbers)

print(product)
# Out:
# 24

# %%
data = {
    "A": 50,
    "B": 20,
    "C": 80
}

result = sorted(data.items(), key=lambda x: x[1])

print(result)
# Out:
# [('B', 20), ('A', 50), ('C', 80)]
