# %% [markdown]
# ## Tuple & List Diff

# %%
fruits = ["Apple","Banana","Mango"]

fruits.append("Orange")
fruits[0]  =  "Graphs"


print(fruits)
# Out:
# ['Graphs', 'Banana', 'Mango', 'Orange']

# %%
colors = ["Red","Blue","Green"]

colors.remove("Green")

print(colors)
# Out:
# ['Red', 'Blue']

# %%
Days = ["Tusesday","Friday","Sunday"]

Days.remove("Friday")

print(Days)
# Out:
# ['Tusesday', 'Sunday']

# %%
data = ["Prerana",22,True]

print(data)
# Out:
# ['Prerana', 22, True]

# %%
# imp for interviwe
numbers = [10,20,30]
numbers.append(40)
print(numbers)
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# ## Tuple

# %%
# creating a tuple

Days = ("Monday","Tuseday","Wensday")

print(Days)
# Out:
# ('Monday', 'Tuseday', 'Wensday')

# %%
# Accessing a tuple
Days=("Monday","tuseday","Wednesday")

print(Days[1])
# Out:
# tuseday

# %%
# tuple with diff data type
student=("Prerana",83.30,"Bca")

print(student)
# Out:
# ('Prerana', 83.3, 'Bca')

# %%
#packing and unpacking
student=(101,"Prerana","Pune")
id , Name , City = student
print(id)
print(Name)
print(City)
print(id,Name,City)
# Out:
# 101
# Prerana
# Pune
# 101 Prerana Pune

# %%
my_list=[1,2,3]
my_list[0]=100
print(my_list)
# Out:
# [100, 2, 3]

# %%
# allows dublicate values
numbers = (10,20,30,40,10)
print(numbers)
# Out:
# (10, 20, 30, 40, 10)

# %%
# Immutable example
colors = ("Red","Blue","Orange")
colors[0] = "Black"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 3
#       1 # Immutable example
#       2 colors = ("Red","Blue","Orange")
# ----> 3 colors[0] = "Black"
#
# TypeError: 'tuple' object does not support item assignment
